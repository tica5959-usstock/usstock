# %% [markdown]
# # 🚀 US Stock Dashboard - Colab Launcher
#
# 이 노트는 **Google Colab**에서 미국 주식 대시보드를 실행하기 위해 만들어졌습니다.
# PC를 켜두지 않아도, 이 노트를 실행하면 스마트폰으로 대시보드에 접속할 수 있습니다.
#
# ### ⚠️ 주의사항
# 1. **Ngrok 토큰 필요**: [Ngrok 가입](https://dashboard.ngrok.com/get-started/your-authtoken) 후 토큰을 아래 코드에 입력해야 합니다.
# 2. **12시간 제한**: Colab 무료 버전은 12시간마다 세션이 초기화됩니다. 꺼지면 다시 '재생' 버튼을 눌러주세요.

# %%
# 1. 환경 설정 및 저장소 다운로드
import os

# 구글 드라이브 마운트 (데이터 영구 저장을 위해)
from google.colab import drive
drive.mount('/content/drive')

# 작업 폴더 생성
project_path = '/content/drive/MyDrive/Stock_Dashboard'
if not os.path.exists(project_path):
    # !git clone https://github.com/tica5959-usstock/usstock.git $project_path
else:
    # %cd $project_path
    # !git pull

# %cd $project_path
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Stock_Dashboard
# Already up to date.
# /content/drive/MyDrive/Stock_Dashboard

# %%
# 2. 필수 라이브러리 설치
# !pip install -r requirements.txt
# !pip install pyngrok flask-ngrok
# Out:
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: yfinance>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (0.2.66)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (2.32.4)
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: google-generativeai>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.8.5)
# Requirement already satisfied: openai>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (2.12.0)
# Requirement already satisfied: seaborn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (0.13.2)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (3.10.0)
# Requirement already satisfied: flask>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (3.1.2)
# Collecting ta>=0.11.0 (from -r requirements.txt (line 12))
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gunicorn>=20.1.0 (from -r requirements.txt (line 13))
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 1)) (2025.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 3)) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 3)) (4.5.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 3)) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 3)) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 3)) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 3)) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 3)) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 3)) (15.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->-r requirements.txt (line 5)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->-r requirements.txt (line 5)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->-r requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->-r requirements.txt (line 5)) (2025.11.12)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.12/dist-packages (from google-generativeai>=0.3.0->-r requirements.txt (line 7)) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from google-generativeai>=0.3.0->-r requirements.txt (line 7)) (2.28.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from google-generativeai>=0.3.0->-r requirements.txt (line 7)) (2.187.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-generativeai>=0.3.0->-r requirements.txt (line 7)) (2.43.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from google-generativeai>=0.3.0->-r requirements.txt (line 7)) (2.12.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from google-generativeai>=0.3.0->-r requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai>=0.3.0->-r requirements.txt (line 7)) (1.26.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.0.0->-r requirements.txt (line 8)) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.0.0->-r requirements.txt (line 8)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.0.0->-r requirements.txt (line 8)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.0.0->-r requirements.txt (line 8)) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.0.0->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (3.2.5)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0.0->-r requirements.txt (line 11)) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0.0->-r requirements.txt (line 11)) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0.0->-r requirements.txt (line 11)) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0.0->-r requirements.txt (line 11)) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0.0->-r requirements.txt (line 11)) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0.0->-r requirements.txt (line 11)) (3.1.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.0->-r requirements.txt (line 3)) (2.8)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance>=0.2.0->-r requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai>=0.3.0->-r requirements.txt (line 7)) (1.72.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai>=0.3.0->-r requirements.txt (line 7)) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai>=0.3.0->-r requirements.txt (line 7)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai>=0.3.0->-r requirements.txt (line 7)) (4.9.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai>=1.0.0->-r requirements.txt (line 8)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0.0->-r requirements.txt (line 8)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai>=0.3.0->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai>=0.3.0->-r requirements.txt (line 7)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai>=0.3.0->-r requirements.txt (line 7)) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai>=0.3.0->-r requirements.txt (line 7)) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai>=0.3.0->-r requirements.txt (line 7)) (0.2.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai>=0.3.0->-r requirements.txt (line 7)) (4.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance>=0.2.0->-r requirements.txt (line 3)) (2.23)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai>=0.3.0->-r requirements.txt (line 7)) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai>=0.3.0->-r requirements.txt (line 7)) (1.71.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai>=0.3.0->-r requirements.txt (line 7)) (0.6.1)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 4.3 MB/s eta 0:00:00
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29412 sha256=2531f448fc1834194f7f33cd6d2096d5a58d39f3c4b806d93bf77561723d9125
#   Stored in directory: /root/.cache/pip/wheels/5c/a1/5f/c6b85a7d9452057be4ce68a8e45d77ba34234a6d46581777c6
# Successfully built ta
# Installing collected packages: gunicorn, ta
# Successfully installed gunicorn-23.0.0 ta-0.11.0
# Collecting pyngrok
#   Downloading pyngrok-7.5.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting flask-ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.12/dist-packages (from flask-ngrok) (3.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from flask-ngrok) (2.32.4)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask>=0.8->flask-ngrok) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from Flask>=0.8->flask-ngrok) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask>=0.8->flask-ngrok) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from Flask>=0.8->flask-ngrok) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask>=0.8->flask-ngrok) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from Flask>=0.8->flask-ngrok) (3.1.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->flask-ngrok) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->flask-ngrok) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->flask-ngrok) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->flask-ngrok) (2025.11.12)
# Downloading pyngrok-7.5.0-py3-none-any.whl (24 kB)
# Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Installing collected packages: pyngrok, flask-ngrok
# Successfully installed flask-ngrok-0.0.25 pyngrok-7.5.0

# %%
# 3. 서버 실행 (Ngrok)
from pyngrok import ngrok

# 여기에 Ngrok 토큰을 입력하세요
NGROK_AUTH_TOKEN = "37mhrdZIOwsATOraezqH6gR7Grq_884PKmfdsacFiTnjaCTau"
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# 포트 열기
public_url = ngrok.connect(5001).public_url
print(f"\n🔥 대시보드 접속 주소: {public_url} \n")

# 앱 실행
# !python flask_app.py
# Out:
# 🔥 대시보드 접속 주소: https://unrentable-foppishly-juanita.ngrok-free.dev
#
# 🚀 Flask Server Starting on port 5001...
#  * Serving Flask app 'flask_app'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5001
# Press CTRL+C to quit
# 127.0.0.1 - - [04/Jan/2026 08:13:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jan/2026 08:13:09] "GET /static/css/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jan/2026 08:13:10] "GET /static/js/dashboard.js HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jan/2026 08:13:10] "GET /api/us/history-dates HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jan/2026 08:13:11] "GET /api/us/options-flow HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jan/2026 08:13:11] "GET /api/us/sector-heatmap HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jan/2026 08:13:11] "GET /api/us/etf-flows HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jan/2026 08:13:12] "GET /api/us/portfolio HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jan/2026 08:13:13] "GET /api/us/smart-money HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jan/2026 08:13:13] "GET /api/us/macro-analysis?lang=ko&model=gemini HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jan/2026 08:13:14] "GET /api/us/stock-chart/NEM?period=1y HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jan/2026 08:13:15] "GET /api/us/technical-indicators/NEM?period=1y HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jan/2026 08:13:15] "GET /api/us/ai-summary/NEM?lang=ko HTTP/1.1" 200 -
